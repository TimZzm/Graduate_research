# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 12, 6
ds_co2_4x_plt.co2.sel(time='0001-01').sel(plev=85000).squeeze().plot()

# %%
ds_co2_4x_plt_500 = ds_co2_4x_plt.sel(plev=50000).drop_vars("plev")
ds_co2_4x_plt_500
co2_timeseries_4x = (ds_co2_4x_plt_500.co2 * ds_area.areacella).sum(dim=['lon', 'lat']) / total_area
array_co2_ts = np.array(co2_timeseries_4x)
year_co2_ts = np.mean(array_co2_ts.reshape(1980//12, 12), axis=1)
plt.plot(year_co2_ts)
plt.show()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 12, 6
ds_co2_his_plt.co2.sel(time='0100-01').sel(plev=20000).squeeze().plot()

# %%
for pres_lev in [100000.,  92500.,  85000.,  70000.,  60000.,  50000.]:
    ds_co2_his_plt_pres = ds_co2_his_plt.sel(plev=pres_lev).drop_vars("plev")
    ds_co2_his_plt_pres
    co2_timeseries_his = (ds_co2_his_plt_pres.co2 * ds_area.areacella).sum(dim=['lon', 'lat']) / total_area
    array_co2_ts = np.array(co2_timeseries_his)
    year_co2_ts = np.mean(array_co2_ts.reshape(150, 12), axis=1)
    plt.plot(year_co2_ts)
    plt.show()
